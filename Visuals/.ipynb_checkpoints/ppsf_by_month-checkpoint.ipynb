# %%
import pandas as pd
import datetime as dt
from pathlib import Path

ppsf_data = Path("../Resources/ppsf.csv")
ppsf_df = pd.read_csv(ppsf_data)
ppsf_df.head()
# Out:
#             Unnamed: 0 Month of Period End Month of Period End.1  \
# 0               Region       February 2012            March 2012
# 1  Maricopa County, AZ                75.5                  78.3
#
#   Month of Period End.2 Month of Period End.3 Month of Period End.4  \
# 0            April 2012              May 2012             June 2012
# 1                  82.3                  86.3                    87
#
#   Month of Period End.5 Month of Period End.6 Month of Period End.7  \
# 0             July 2012           August 2012        September 2012
# 1                  87.3                  88.6                  91.1
#
#   Month of Period End.8  ... Month of Period End.116 Month of Period End.117  \
# 0          October 2012  ...            October 2021           November 2021
# 1                    92  ...                   251.7                   256.4
#
#   Month of Period End.118 Month of Period End.119 Month of Period End.120  \
# 0           December 2021            January 2022           February 2022
# 1                   257.6                   262.6                   270.4
#
#   Month of Period End.121 Month of Period End.122 Month of Period End.123  \
# 0              March 2022              April 2022                May 2022
# 1                   279.1                   287.3                   292.8
#
#   Month of Period End.124 Month of Period End.125
# 0               June 2022               July 2022
# 1                   290.3                   282.7
#
# [2 rows x 127 columns]

# %%
# transform table, reset index, and drop row [0]

ppsf_df = ppsf_df.T
ppsf_df.reset_index(drop=True, inplace=True)
ppsf_df.drop(ppsf_df.index[0], inplace=True)
ppsf_df
# Out:
#                  0      1
# 1    February 2012   75.5
# 2       March 2012   78.3
# 3       April 2012   82.3
# 4         May 2012   86.3
# 5        June 2012     87
# ..             ...    ...
# 122     March 2022  279.1
# 123     April 2022  287.3
# 124       May 2022  292.8
# 125      June 2022  290.3
# 126      July 2022  282.7
#
# [126 rows x 2 columns]

# %%
ppsf_df[1]=ppsf_df[1].astype(float)
ppsf_df
# Out:
#                  0      1
# 1    February 2012   75.5
# 2       March 2012   78.3
# 3       April 2012   82.3
# 4         May 2012   86.3
# 5        June 2012   87.0
# ..             ...    ...
# 122     March 2022  279.1
# 123     April 2022  287.3
# 124       May 2022  292.8
# 125      June 2022  290.3
# 126      July 2022  282.7
#
# [126 rows x 2 columns]

# %%
ppsf_df.plot(x=0,y=1,rot=90,figsize=(20,10),title='Price per Square Foot by Year - Maricopa County', ylabel='Price per Square Foot',grid=True, fontsize=18)
# Out:
# <AxesSubplot:title={'center':'Price per Square Foot by Year - Maricopa County'}, xlabel='0', ylabel='Price per Square Foot'>

# %%
ppsf_df[2] = ppsf_df[1].pct_change()
ppsf_df.plot(x=0,y=2, rot=90,figsize=(20,10), grid=True, title='Percent Change in PPSF over Time - Maricopa County', ylabel='Percent Change of PPSF')
# Out:
# <AxesSubplot:title={'center':'Percent Change in PPSF over Time - Maricopa County'}, xlabel='0', ylabel='Percent Change of PPSF'>
