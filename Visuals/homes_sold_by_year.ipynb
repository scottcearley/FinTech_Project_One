# %%
import pandas as pd
import datetime as dt
from pathlib import Path

homes_sold_data = Path("../Project_One/Resources/homes_sold.csv")
homes_sold_df = pd.read_csv(homes_sold_data)
homes_sold_df.head()
# Out:
#    Day of Year  Year of Period End Period Begin Period End  \
# 0            2                2022    12/6/2021   1/2/2022
# 1            3                2021    12/7/2020   1/3/2021
# 2            5                2020    12/9/2019   1/5/2020
# 3            6                2019   12/10/2018   1/6/2019
# 4            9                2022   12/13/2021   1/9/2022
#
#   adjusted_average_homes_sold  adjusted_average_homes_sold_yoy  \
# 0                       1,879                        -0.026929
# 1                       1,931                         0.245003
# 2                       1,551                         0.116631
# 3                       1,389                        -0.095703
# 4                       1,796                        -0.036481
#
#   Average Homes Sold Yoy (tooltip)
# 0                            -2.7%
# 1                            24.5%
# 2                            11.7%
# 3                            -9.6%
# 4                            -3.6%

# %%
homes_sold_df['adjusted_average_homes_sold']=homes_sold_df['adjusted_average_homes_sold'].str.replace(',','').astype(float)

# %%
homes_sold_df.dtypes
# Out:
# Day of Year                           int64
# Year of Period End                    int64
# Period Begin                         object
# Period End                           object
# adjusted_average_homes_sold         float64
# adjusted_average_homes_sold_yoy     float64
# Average Homes Sold Yoy (tooltip)     object
# dtype: object

# %%
#homes_sold_df.dtypes
homes_sold_df.plot(x="Period End", y="adjusted_average_homes_sold")
# Out:
# <AxesSubplot:xlabel='Period End'>
